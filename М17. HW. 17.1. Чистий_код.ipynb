# %% [markdown]
# У завданнях 1-4. Вам наданий простий код на Python, який не відповідає вказівкам PEP8. Ваше завдання — відредагувати код так, аби він відповідав PEP8. Напишіть після редагуванню коду, дотримання яких правил з pep8 ви досягли в відредагованій версі, наприклад
# ```
# - додала пробіли навколо бінарного оператора
# - додала два порожні рядки між визначеннями функцій
# і тд
# ```
# Також можна зазанчити використані правила коментарями по коду, а не окремим повідомленням.
#
# Відредагований код має виконувати весь той самий функціонал, але бути написаний відповідно до вимог до гарного коду на Python! Не забудьте запустити відредагований код, він має бути робочим.

# %% [markdown]
# Завдання 1.

# %%
def greet(name):print(f"Hello, {name}")
def add(n1,n2):return n1+n2

x = 5;y = 3
display(greet("John"),add(x,y))
# Out:
# Hello, John
# None
# 8

# %%
def greet(name: str) -> None:
    print(f"Hello, {name}")  # Додала print на окремий рядок


# Додала два порожні рядки між визначеннями функцій
def add(n1: int, n2: int) -> int:  # Додала пробіли після коми
    return n1 + n2  # Додала пробіли навколо бінарного оператора


x = 5  # Розбила один рядок на окремі
y = 3

greet("John")
print(add(x, y))  # Додала пробіл після коми
# Out:
# Hello, John
# 8

# %% [markdown]
# Завдання 2.

# %%
from math import *
def calcArea(r):return pi*r**2
def calcCircumference(r):return 2*pi*r

radius=5
print("Area:",calcArea(radius),"Circumference:",calcCircumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %%
import math  # Замінила import * на явний імпорт модуля


# Перейменувала функції відповідно до snake_case
def calc_area(r: float) -> float:  # Перенесла return на окремий рядок
    return math.pi * r**2  # Додала пробіли навколо бінарних операторів


# Додала два порожні рядки між визначеннями функцій
def calc_circumference(r: float) -> float:
    return 2 * math.pi * r


radius = 5

# Використала f-string для форматування рядка
print(f"Area: {calc_area(radius)}, Circumference: {calc_circumference(radius)}")
# Out:
# Area: 78.53981633974483, Circumference: 31.41592653589793

# %% [markdown]
# Завдання 3.

# %%
class animal: pass
class dog(animal):
    def __init__(self,name):
        self.name=name
        self.type='Dog'

# %%
class Animal:  # Перейменувала класи відповідно до CamelCase
    pass  # Перенесла на окремий рядок


# Додала два порожні рядки між визначеннями класів
class Dog(Animal):
    def __init__(self, name: str) -> None:  # Додала пробіли після коми
        self.name = name  # Додала пробіли навколо оператора присвоєння
        self.type = "Dog"

# %% [markdown]
# Завдання 4.

# %%
list=[1,2,3,4,5]
for i in range(len(list)):print(list[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Перейменувала змінну list
my_list = [1, 2, 3, 4, 5]  # Додала пробіли навколо оператора присвоєння і після ком

for item in my_list:  # Використала ідіому python 
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 5.У вас є DataFrame df, що представляє результати тестів студентів з математики, англійської мови та історії. Поточний код обчислює середній бал для кожного студента шляхом ітерації за рядками DataFrame за допомогою iterrows().
#
# Ваше завдання полягає в тому, щоб змінити код так, аби уникнути використання iterrows() і замість цього застосувати більш ефективне та читабельне рішення відповідно до правил, озвучених у лекції. Рефакторинг треба зробити лише частині, де рахуються середні, імпорт і визначення датафрейму лишаємо без змін.

# %%
import pandas as pd

df = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Charlie', 'David'],
    'math_score': [89, 94, 77, 85],
    'english_score': [92, 88, 79, 85],
    'history_score': [84, 92, 81, 89]
})

# %%
averages = []
for _, row in df.iterrows():
    averages.append((row['math_score'] + row['english_score'] + row['history_score']) / 3)

df['average_score'] = averages

# %%
df["average_score"] = df[
    ["math_score", "english_score", "history_score"]
].mean(axis=1)

# %% [markdown]
# 6.У Вас є великий DataFrame df, що представляє транзакції продажу в магазині. Цей DataFrame містить понад 1 мільйон рядків і кілька стовпців, зокрема «product_name», «product_category», «product_price» і «transaction_date».
#
# І «product_name», і «product_category» є рядками, що представляють численні, але обмежені унікальні назви продуктів і категорії відповідно.
#
# Напишіть код для ефективного перетворення стовпців «product_name» і «product_category» на категорійний тип для ефективного використання пам’яті.
# Спробуйте вирішити це завдання, мінімізуючи використання пам'яті та зберігаючи читабельність коду. Крім того, виміряйте використання пам’яті до та після перетворення, щоб продемонструвати підвищення ефективності.
#
# Порівняйте кількість памʼяті, яку займає наданий набір даних і новий, створений Вами. В лекції був приклад. В скільки разів менше памʼяті займає новий датафрейм?

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

products = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
categories = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']

N_ROWS = 10**6
df = pd.DataFrame({
    'product_name': np.random.choice(products, N_ROWS),
    'product_category': np.random.choice(categories, N_ROWS),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h')
})

before = df.memory_usage(index=False).sum()

# %%
for col in df[['product_name', 'product_category']]:
    df[col] = pd.Categorical(df[col])

after = df.memory_usage(index=False).sum()

print(f"Було: {before:,} байт")
print(f"Стало: {after:,} байт")
print(f"Витрати пам'яті знизились у {before / after:.2f} рази!")
# Out:
# Було: 32,000,000 байт
# Стало: 18,000,048 байт
# Витрати пам'яті знизились у 1.78 рази!

# %% [markdown]
# 7.В цьому завданні кілька пунктів. Треба виконати усі послідовно.
#     7.1. Завантажте дані у pandas dataframe з файла `ecommerce_data.csv`. Обовʼязково при завантаженні вкажіть параметр `encoding = 'ISO-8859-1'`, без нього буде помилка.
#     7.2. Заповніть пропущені значення в колонці CustomerID на -1 та перетворіть тип цієї колонки на str, адже зараз вона типу float, а це не правильний тип даних для ідентифікатора клієнта.
#     7.3. З допомогою бібліотеки sweetviz побудуйте html звіт, який порівнює дані для країни "Germany" і країни "France". У Вас можуть виникнути багато попереджень (Warning), їх рекомендую вимкнути наступним шматком коду
#
#
#     import warnings
#
#     with warnings.catch_warnings(record=True):
#         # your code
#
#
#    7.4.Напишіть 5 відмінностей для двох зазначених країн на основі побудованого звіту, без виконання додаткового аналізу іншими інструментами.

# %%
df_ecommerce = pd.read_csv('../data/ecommerce_data.csv', encoding='ISO-8859-1')
df_ecommerce.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  str
#  1   StockCode    541909 non-null  str
#  2   Description  540455 non-null  str
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  str
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 33.1 MB

# %%
df_ecommerce["CustomerID"] = df_ecommerce["CustomerID"].fillna(-1).astype(int).astype(str)
df_ecommerce.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55      17850  United Kingdom
# 1  12/1/2010 8:26       3.39      17850  United Kingdom
# 2  12/1/2010 8:26       2.75      17850  United Kingdom

# %%
import sweetviz as sv
import warnings

df_germany = df_ecommerce[df_ecommerce["Country"] == "Germany"]
df_france = df_ecommerce[df_ecommerce["Country"] == "France"]

with warnings.catch_warnings(record=True):
    report = sv.compare(
        [df_germany, "Germany"],
        [df_france, "France"],
    )

report.show_html("germany_vs_france.html", open_browser=True)
# Out:
# C:\Users\shevc\anaconda3\envs\da-hw17\Lib\site-packages\sweetviz\graph.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
#                                              |                                                                …
# Report germany_vs_france.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# **5 відмінностей:**
# - У Німеччині зафіксовано більше транзакцій (9 495) порівняно з Францією (8 557). Також у Німеччині більше унікальних інвойсів (603 проти 461), що свідчить про вищу кількість окремих замовлень;
# - У Німеччині продається більше унікальних товарів (1 671), ніж у Франції (1 543). Це можу свідчити про ширший асортимент або більш різноманітний попит на німецькому ринку;
# - У Франції спостерігається більша кількість товарів в одній транзакції (912 проти 600 у Німеччині). Крім того, у Франції вищі показники стандарного відхилення (21.4 проти 17.9) та варіації (459 проти 319), що свідчить про більшу варіативність обсягу покупок.
# - Франція демонструє значно вищу максимальну ціну за одиницю товару (4 161 проти 600 у Німеччині). Також у Франції суттєво більший розкид цін (стандартне відхилення - 79.9 і варіація - 6 385), що вказує на наявність значно дорожчих товарів.
# - У Німеччині дещо більше унікальних клієнтів (95 проти 88 у Франції), що може вказувати на ширшу клієнтську базу.

# %% [markdown]
# 8.З допомогою ChatGPT виявіть, чи є та які помилки в наступному коді.
# Попросіть після цього переписати код із дотриманням PEP8. Проаналізуйте результат. Чи справді ChatGPT виправив всі стилістичні помилки? Якщо ні, напишіть йому ще кілька запитів, аби код відповідав вимогам PEP8.
# Вставте фінальну версію коду з чату у ноутбук та запустіть на заданому списку. Має вертатись 50.
# Напишіть, які промпти (інструкції) при зверненні до ChatGPT ви застосували та додайте скріншот(-и) з промптами та відповідями чата.
# Якщо зробили висновки при виконанні цього завдання, то діліться також :)
#
# **ЯК ВСТАВИТИ СКРІНШОТ в Jupyter Notebook** :
# 1. Створіть нову Markdown клітинку
# 2. В новоствореній клітинці обираєте в меню Jupyter Notebook Edit -> Insert Image
# 3. Обираєте картинку
# 4. В клітинці має зʼявитись текст, який містить картинку. Запустіть клітинку.
#
# Або можна просто перетягнути картинку в Markdown клітинку.

# %%
def CalculateVariance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    return mean_squares

# %%
input_list = [75, 80, 85, 90, 95]

# %%
def calculate_variance(numbers: list) -> float:
    """
    Calculate population variance for a list of numbers.
    """

    if not numbers:
        raise ValueError("The list of numbers must not be empty.")

    mean = sum(numbers) / len(numbers)
    mean_squares = sum(n**2 for n in numbers) / len(numbers)

    return mean_squares - mean**2

# %%
calculate_variance(input_list)
# Out:
# 50.0

# %% [markdown]
# ![Снимок экрана 2026-02-26 172049.png](attachment:07be2a96-b501-4059-b645-2dfef5fdd0f5.png)

# %% [markdown]
# ![Снимок экрана 2026-02-26 172109.png](attachment:ee0579f9-8148-4e26-b0c4-d6dfc6745961.png)

# %% [markdown]
# ![Снимок экрана 2026-02-26 172125.png](attachment:99573ca6-3299-4037-af60-d5ffbfb62365.png)

# %% [markdown]
# ![Снимок экрана 2026-02-26 172140.png](attachment:13125324-146a-4e2d-b5a5-309b983699de.png)

# %% [markdown]
# ![Снимок экрана 2026-02-26 172152.png](attachment:9524f87b-5953-4353-930c-7ef8c438ee66.png)

# %% [markdown]
# ![Снимок экрана 2026-02-26 172213.png](attachment:ae49f1e7-be99-45cc-834e-c57d4a88ae59.png)

# %% [markdown]
# ![Снимок экрана 2026-02-26 172222.png](attachment:3cc0cf99-d081-46b5-bb61-dce6c9cd8956.png)
